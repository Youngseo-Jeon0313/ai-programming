# %% [markdown]
# # AI 프로그래밍 과제 1

# %% [markdown]
# ## Problem 1: 연속적인 구구단 계산기 프로그램을 만들어 보자.

# %% [markdown]
# ## 이 프로그램의 규칙은 다음과 같다.

# %% [markdown]
# - 프로그램이 시작되면 '구구단 몇 단을 계산할까요(1~9)?'가 출력된다
# - 사용자는 계산하고 싶은 구구단 숫자를 입력한다.
# - 프로그램은 '구구단 n단을 계산합니다.' 라는 메세지와 함께 구구단의 결과를 출력한다. (n은 사용자가 입력한 n단)
# - 프로그램이 계속 실행되다가 종료 조건에 해당하는 숫자(0)를 사용자가 입력하면 프로그램이 종료된다.

# %%
print("구구단 몇 단을 계산할까요(1~9)?")

# %% [markdown]
# ## Problem 1의 프로그램을 완성하기 위해 아래에 코드를 채우시오.

# %%
"""
Problem 1. 이 셀 안에 코드를 작성하시오.
"""
n=1
while True:
    n=int(input())
    if n==0: break
    print(f'구구단 {n}단을 계산합니다.')
    for i in range(1,10):
        print(n,'x',i,'=',n*i)
    print('구구단 몇 단을 계산할까요(1~9)?')
print('구구단 게임을 종료합니다.')
# Out:
# 7
# 구구단 7단을 계산합니다.
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 구구단 몇 단을 계산할까요(1~9)?
# 9
# 구구단 9단을 계산합니다.
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 구구단 몇 단을 계산할까요(1~9)?
# 0
# 구구단 게임을 종료합니다.

# %% [markdown]
# ## Problem 2: 리스트안에 홀수가 총 몇 개 포함되어 있는지 찾아주는 프로그램을 만들어 보자.

# %% [markdown]
# ## 이 프로그램의 규칙은 다음과 같다.
# - 프로그램은 마지막에 '리스트안의 홀수 갯수: n' 라는 메세지와 함께 주어진 numbers라는 리스트안에 포함된 홀수의 갯수를 결과로 출력한다. (n은 실제 갯수)

# %%
numbers = [9,13,8,45,22,97,75,56,34,25,2,66,81,43]

# %%
"""
Problem 2. 이 셀 안에 코드를 작성하시오.
"""

odds=0
for i in numbers:
    if i%2==1:
        odds+=1
print('리스트안의 홀수갯수:',odds)
# Out:
# 리스트안의 홀수갯수: 8
